# %% [markdown]
# <a href="https://colab.research.google.com/github/josele73/Contaste-Google-maps-y-Datos-catastrales/blob/main/Contraste_datos_google_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# !pip3 install pyproj
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-search-results
#   Downloading google_search_results-2.4.1.tar.gz (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from google-search-results) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->google-search-results) (3.0.4)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25789 sha256=476d29e57908802d3749980dde89654ebbf592f2b7fffc66f675e69af1dab4e1
#   Stored in directory: /root/.cache/pip/wheels/82/a3/c5/364155118f298722dff2f79ae4dd7c91e92b433ad36d6f7e0e
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyproj
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 5.3 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj) (2022.9.24)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.2.1

# %%
import os
from serpapi import GoogleSearch
import pandas as pd
import numpy as np 
import pyproj
from pyproj import Transformer

# %%
# Descargamos los datos de googe con serpapi

# %%
from google.colab import drive

#Contamos drive
drive.mount('/content/drive')
path = '/content/gdrive/My Drive/' # the absolute path to your file
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#leemos el CSV
df = pd.read_csv('drive/MyDrive/Colab Notebooks/datos_google/google-maps-alojamiento-data3.csv')
df.head(3)
# Out:
#    position               title                     place_id  \
# 0         1  MyFlats Urban Stay  ChIJYWKUQkg3Yg0RLJg6VyMTUM4
# 1         2     LC Hotel Urbano  ChIJ72mMRwY3Yg0RJhb5NIMK8Uo
# 2         3        Hostal Mayor  ChIJv69ug7E3Yg0R7bn5medZvEM
#
#                                 data_id              data_cid  \
# 0  0xd62374842946261:0xce501323573a982c  14866403412458248236
# 1  0xd623706478c69ef:0x4af10a8334f91626   5400108986839668262
# 2  0xd6237b1836eafbf:0x43bc59e799f9b9ed   4880874947418372589
#
#                                         reviews_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                          photos_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                      gps_coordinates  \
# 0  {'latitude': 38.3463358, 'longitude': -0.4863132}
# 1  {'latitude': 38.345733599999996, 'longitude': ...
# 2    {'latitude': 38.34483, 'longitude': -0.4827743}
#
#                                      place_id_search  rating  ...  \
# 0  https://serpapi.com/search.json?data=%214m5%21...     4.5  ...
# 1  https://serpapi.com/search.json?data=%214m5%21...     3.9  ...
# 2  https://serpapi.com/search.json?data=%214m5%21...     3.3  ...
#
#               phone                                     website  \
# 0  +34 654 88 43 73                      http://www.myflats.es/
# 1  +34 600 85 72 14  https://sites.google.com/view/urban-hotel/
# 2  +34 639 99 00 55     https://www.hotelesyo.com/hostal-mayor/
#
#           amenities                                          thumbnail  \
# 0  ['Wi-Fi gratis']  https://lh5.googleusercontent.com/p/AF1QipPKPq...
# 1  ['Wi-Fi gratis']  //lh3.googleusercontent.com/proxy/cGm67uviLSdD...
# 2               NaN  //lh6.googleusercontent.com/proxy/2TsZsfNoKpGD...
#
#                                          description unclaimed_listing  \
# 0                                                NaN               NaN
# 1  Hotel sencillo con habitaciones informales. Ha...               NaN
# 2  Hostal informal con habitaciones amplias. Host...              True
#
#   open_state hours operating_hours service_options
# 0        NaN   NaN             NaN             NaN
# 1        NaN   NaN             NaN             NaN
# 2        NaN   NaN             NaN             NaN
#
# [3 rows x 24 columns]

# %%
def extraercoordenadas(texto):
  c=texto.split(",")
  lon = (c[0][13:len(c[0])])
  lat = (c[1][14:len(c[1])-1])
  return (lon,lat)

# %%
#Añadir al dafaframe la longuitud y latitud ws84 y epgs25830
longui = []
lati = []
lon_25830 = []
lat_25830 = []

#Coordendas WS84
coord = df['gps_coordinates']

#extraer coordenadas en WS84 y transformar a 25830
for n in range(len(df.index)):

  lon, lat = extraercoordenadas(coord[n])
  longui.append(lon)
  lati.append(lat)
  
  #tranformamos a 25830
  transformer = Transformer.from_crs("epsg:4326", "epsg:25830")
  x2,y2 = transformer.transform(lon,lat)
  lon_25830.append(x2)
  lat_25830.append(y2)
  
#Listas de coordenadas al dataframe
df['lon_ws84'] = longui
df['lat_ws84'] = lati
df['lon_25830'] = lon_25830
df['lat_25830'] = lat_25830

df.head(3)
# Out:
#    position               title                     place_id  \
# 0         1  MyFlats Urban Stay  ChIJYWKUQkg3Yg0RLJg6VyMTUM4
# 1         2     LC Hotel Urbano  ChIJ72mMRwY3Yg0RJhb5NIMK8Uo
# 2         3        Hostal Mayor  ChIJv69ug7E3Yg0R7bn5medZvEM
#
#                                 data_id              data_cid  \
# 0  0xd62374842946261:0xce501323573a982c  14866403412458248236
# 1  0xd623706478c69ef:0x4af10a8334f91626   5400108986839668262
# 2  0xd6237b1836eafbf:0x43bc59e799f9b9ed   4880874947418372589
#
#                                         reviews_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                          photos_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                      gps_coordinates  \
# 0  {'latitude': 38.3463358, 'longitude': -0.4863132}
# 1  {'latitude': 38.345733599999996, 'longitude': ...
# 2    {'latitude': 38.34483, 'longitude': -0.4827743}
#
#                                      place_id_search  rating  ...  \
# 0  https://serpapi.com/search.json?data=%214m5%21...     4.5  ...
# 1  https://serpapi.com/search.json?data=%214m5%21...     3.9  ...
# 2  https://serpapi.com/search.json?data=%214m5%21...     3.3  ...
#
#                                          description unclaimed_listing  \
# 0                                                NaN               NaN
# 1  Hotel sencillo con habitaciones informales. Ha...               NaN
# 2  Hostal informal con habitaciones amplias. Host...              True
#
#   open_state hours operating_hours service_options            lon_ws84  \
# 0        NaN   NaN             NaN             NaN          38.3463358
# 1        NaN   NaN             NaN             NaN  38.345733599999996
# 2        NaN   NaN             NaN             NaN            38.34483
#
#                lat_ws84      lon_25830     lat_25830
# 0            -0.4863132  719669.409462  4.247233e+06
# 1  -0.48552059999999997  719740.505463  4.247169e+06
# 2            -0.4827743  719983.275822  4.247075e+06
#
# [3 rows x 28 columns]

# %%
#Librerias necesarias para obetener referencias catatrales desde coordendas WS84 en cartociudad
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
# ejemplo quote_page = "https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon=-0.4352541&lat=38.3624766&type=refcatastral"
quote_page = 'https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon='+lat+'&lat='+lon+'&type=refcatastral'

page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')

print(soup)
print(quote_page)
# Out:
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0273703YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4805 38.34503)","tip_via":null,"lat":38.34503,"lng":-0.4805,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PZ AJUNTAMENT 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon=-0.4805&lat=38.34503&type=refcatastral

# %%
#Extraer datos de las coordenadas en cartociudad. Importante: referencia catastral
for z in range(len(df.index)):
  
  lon, lat = extraercoordenadas(coord[z])
  quote_page = 'https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon='+lat+'&lat='+lon+'&type=refcatastral'
  page = urlopen(quote_page)
  soup = BeautifulSoup(page, 'html.parser')
  
  if len(soup) == 0:
    print("NO LOCALIZADO")
  else:
    print(soup)
# Out:
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9874117YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4863132 38.3463358)","tip_via":null,"lat":38.3463358,"lng":-0.4863132,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL BAZAN 40 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9873408YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4855206 38.345733599999996)","tip_via":null,"lat":38.345733599999996,"lng":-0.48552059999999997,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL CASTAÃ‘OS 30 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# NO LOCALIZADO
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0071402YH2407A","postalCode":null,"poblacion":null,"geom":"POINT (-0.4831661 38.3439651)","tip_via":null,"lat":38.3439651,"lng":-0.4831661,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"RB MENDEZ NUÃ‘EZ 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0073202YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4836582 38.3454443)","tip_via":null,"lat":38.3454443,"lng":-0.4836582,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"RB MENDEZ NUÃ‘EZ 24 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9773312YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4870351 38.3456495)","tip_via":null,"lat":38.3456495,"lng":-0.4870351,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL NAVAS LAS 30 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0172302YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4828056 38.3444139)","tip_via":null,"lat":38.3444139,"lng":-0.4828056,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL RAFAEL ALTAMIRA 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9773313YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4870639 38.3457933)","tip_via":null,"lat":38.3457933,"lng":-0.4870639,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL NAVAS LAS 32 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9872402YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4855938 38.3448376)","tip_via":null,"lat":38.3448376,"lng":-0.48559379999999996,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL SANTA BARBARA 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0073806YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.48298 38.345237999999995)","tip_via":null,"lat":38.345237999999995,"lng":-0.48297999999999996,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PZ ABAD PENALVA 1 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0172609YH2407A","postalCode":null,"poblacion":null,"geom":"POINT (-0.4815088 38.3446156)","tip_via":null,"lat":38.3446156,"lng":-0.48150879999999996,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL M.JOSEFA AGREDA Y MUÃ‘OZ 2 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0072203YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4836213 38.3447564)","tip_via":null,"lat":38.3447564,"lng":-0.4836213,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"RB MENDEZ NUÃ‘EZ 9 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0173519YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4820983 38.3457821)","tip_via":null,"lat":38.3457821,"lng":-0.4820983,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL SAN NICOLAS 14 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0072203YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.483771 38.3447075)","tip_via":null,"lat":38.3447075,"lng":-0.48377099999999995,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"RB MENDEZ NUÃ‘EZ 9 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9972803YH1497B","postalCode":null,"poblacion":null,"geom":"POINT (-0.4844413 38.3441111)","tip_via":null,"lat":38.3441111,"lng":-0.48444129999999996,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL SAN FRANCISCO 10 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0172610YH2407A","postalCode":null,"poblacion":null,"geom":"POINT (-0.481431 38.344498)","tip_via":null,"lat":38.344498,"lng":-0.481431,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL SAN FERNANDO 6 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0073401YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4834725 38.3456723)","tip_via":null,"lat":38.3456723,"lng":-0.48347249999999997,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL SAN ISIDRO 4 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9872404YH1497D","postalCode":null,"poblacion":null,"geom":"POINT (-0.4852222 38.344636099999995)","tip_via":null,"lat":38.344636099999995,"lng":-0.4852222,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"CL CASTAÃ‘OS 7 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0273703YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4805 38.34503)","tip_via":null,"lat":38.34503,"lng":-0.4805,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PZ AJUNTAMENT 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"0273703YH2407C","postalCode":null,"poblacion":null,"geom":"POINT (-0.4805 38.34503)","tip_via":null,"lat":38.34503,"lng":-0.4805,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PZ AJUNTAMENT 3 ALICANTE/ALACANT (ALICANTE)","countryCode":"011"}

# %%
#Extraer y listar referencias catastrales y enlaces fotografia e informacion parcela en  catastro
referencias = []
web_foto = []
info_catastro = []

for z in range(len(df.index)):

  lon, lat = extraercoordenadas(coord[z])
  quote_page = 'https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon='+lat+'&lat='+lon+'&type=refcatastral'
  page = urlopen(quote_page)
  soup = BeautifulSoup(page, 'html.parser')
  texto = str(soup)
  pos = texto.rfind('address')
  
  if len(soup) == 0:
    ref_cat = '00000000000000'
  else:
    ref_cat = texto[pos+10:pos+24]
    
  web = 'http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLibres/OVCFotoFachada.svc/RecuperarFotoFachadaGet?ReferenciaCatastral='+ref_cat
  web_cat = "https://www1.sedecatastro.gob.es/CYCBienInmueble/OVCListaBienes.aspx?del=3&rc1="+ref_cat[0:7]+"&rc2="+ref_cat[7:14]+"'"
  info_catastro.append(web_cat)
  referencias.append(ref_cat)
  web_foto.append(web)

# %%
df['foto_catastral'] = web_foto
df['ref_cat'] = referencias
df['info_catastro'] = info_catastro
df.head(3)
# Out:
#    position               title                     place_id  \
# 0         1  MyFlats Urban Stay  ChIJYWKUQkg3Yg0RLJg6VyMTUM4
# 1         2     LC Hotel Urbano  ChIJ72mMRwY3Yg0RJhb5NIMK8Uo
# 2         3        Hostal Mayor  ChIJv69ug7E3Yg0R7bn5medZvEM
#
#                                 data_id              data_cid  \
# 0  0xd62374842946261:0xce501323573a982c  14866403412458248236
# 1  0xd623706478c69ef:0x4af10a8334f91626   5400108986839668262
# 2  0xd6237b1836eafbf:0x43bc59e799f9b9ed   4880874947418372589
#
#                                         reviews_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                          photos_link  \
# 0  https://serpapi.com/search.json?data_id=0xd623...
# 1  https://serpapi.com/search.json?data_id=0xd623...
# 2  https://serpapi.com/search.json?data_id=0xd623...
#
#                                      gps_coordinates  \
# 0  {'latitude': 38.3463358, 'longitude': -0.4863132}
# 1  {'latitude': 38.345733599999996, 'longitude': ...
# 2    {'latitude': 38.34483, 'longitude': -0.4827743}
#
#                                      place_id_search  rating  ...  hours  \
# 0  https://serpapi.com/search.json?data=%214m5%21...     4.5  ...    NaN
# 1  https://serpapi.com/search.json?data=%214m5%21...     3.9  ...    NaN
# 2  https://serpapi.com/search.json?data=%214m5%21...     3.3  ...    NaN
#
#   operating_hours service_options            lon_ws84              lat_ws84  \
# 0             NaN             NaN          38.3463358            -0.4863132
# 1             NaN             NaN  38.345733599999996  -0.48552059999999997
# 2             NaN             NaN            38.34483            -0.4827743
#
#        lon_25830     lat_25830  \
# 0  719669.409462  4.247233e+06
# 1  719740.505463  4.247169e+06
# 2  719983.275822  4.247075e+06
#
#                                       foto_catastral         ref_cat  \
# 0  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...  9874117YH1497D
# 1  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...  9873408YH1497D
# 2  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...  00000000000000
#
#                                        info_catastro
# 0  https://www1.sedecatastro.gob.es/CYCBienInmueb...
# 1  https://www1.sedecatastro.gob.es/CYCBienInmueb...
# 2  https://www1.sedecatastro.gob.es/CYCBienInmueb...
#
# [3 rows x 31 columns]

# %%
from google.colab import files
		
df_salida = df[['title','ref_cat','address','website','type','phone','info_catastro','foto_catastral','gps_coordinates','lon_ws84','lat_ws84','lon_25830','lat_25830']].copy()
df_salida.head(3)
# Out:
#                 title         ref_cat  \
# 0  MyFlats Urban Stay  9874117YH1497D
# 1     LC Hotel Urbano  9873408YH1497D
# 2        Hostal Mayor  00000000000000
#
#                                        address  \
# 0        Cl. Bazán, 40, 03001 Alicante, España
# 1  Carrer Castaños, 30, 03001 Alicante, España
# 2          C. Mayor, 5, 03002 Alicante, España
#
#                                       website   type             phone  \
# 0                      http://www.myflats.es/  Hotel  +34 654 88 43 73
# 1  https://sites.google.com/view/urban-hotel/  Hotel  +34 600 85 72 14
# 2     https://www.hotelesyo.com/hostal-mayor/  Hotel  +34 639 99 00 55
#
#                                        info_catastro  \
# 0  https://www1.sedecatastro.gob.es/CYCBienInmueb...
# 1  https://www1.sedecatastro.gob.es/CYCBienInmueb...
# 2  https://www1.sedecatastro.gob.es/CYCBienInmueb...
#
#                                       foto_catastral  \
# 0  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...
# 1  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...
# 2  http://ovc.catastro.meh.es/OVCServWeb/OVCWcfLi...
#
#                                      gps_coordinates            lon_ws84  \
# 0  {'latitude': 38.3463358, 'longitude': -0.4863132}          38.3463358
# 1  {'latitude': 38.345733599999996, 'longitude': ...  38.345733599999996
# 2    {'latitude': 38.34483, 'longitude': -0.4827743}            38.34483
#
#                lat_ws84      lon_25830     lat_25830
# 0            -0.4863132  719669.409462  4.247233e+06
# 1  -0.48552059999999997  719740.505463  4.247169e+06
# 2            -0.4827743  719983.275822  4.247075e+06

# %%
#exportar csv a descargas
df_salida.to_csv('output.csv',encoding = 'utf-8-sig',sep = ';') 
files.download('output.csv')


#HASTA AQUI TODO OK

# %%
#Aqui empezamos a trabajar con los diccionarios
#
#
#
#
#
#
#
#
#
#

# %%
c=coord[0].split(",")
lon,lat=(c[0][13:23]),(c[1][14:23])
quote_page = 'https://www.cartociudad.es/geocoder/api/geocoder/reverseGeocode?lon='+lat+'&lat='+lon+'&type=refcatastral'
page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')
print(soup)
# Out:
# {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9751819YH3695S","postalCode":null,"poblacion":null,"geom":"POINT (-0.253389 38.4993434)","tip_via":null,"lat":38.4993434,"lng":-0.253389,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PL PARAIS NORD PP 24 142 VILLAJOYOSA / LA VILA JOIOSA (ALICANTE)","countryCode":"011"}

# %%
import json
 
# initializing string
test_string = str(soup)
 
# printing original string
print("The original string : " + str(test_string))
 
# using json.loads()
# convert dictionary string to dictionary
res = json.loads(test_string)
 
# print result
print("The converted dictionary : " + str(res))
# Out:
# The original string : {"id":null,"province":null,"comunidadAutonoma":null,"muni":null,"type":null,"address":"9751819YH3695S","postalCode":null,"poblacion":null,"geom":"POINT (-0.253389 38.4993434)","tip_via":null,"lat":38.4993434,"lng":-0.253389,"portalNumber":0,"stateMsg":"","extension":null,"state":0,"priority":0,"refCatastral":"PL PARAIS NORD PP 24 142 VILLAJOYOSA / LA VILA JOIOSA (ALICANTE)","countryCode":"011"}
# The converted dictionary : {'id': None, 'province': None, 'comunidadAutonoma': None, 'muni': None, 'type': None, 'address': '9751819YH3695S', 'postalCode': None, 'poblacion': None, 'geom': 'POINT (-0.253389 38.4993434)', 'tip_via': None, 'lat': 38.4993434, 'lng': -0.253389, 'portalNumber': 0, 'stateMsg': '', 'extension': None, 'state': 0, 'priority': 0, 'refCatastral': 'PL PARAIS NORD PP 24 142 VILLAJOYOSA / LA VILA JOIOSA (ALICANTE)', 'countryCode': '011'}

# %%
type(res)
pdd=pd.DataFrame.from_dict([res])
pdd
type(res)
pdd2=pd.DataFrame.from_dict([res])
pdd2
pdd3=pd.concat([pdd, pdd2], ignore_index=True)
pdd3
# Out:
#      id province comunidadAutonoma  muni  type         address postalCode  \
# 0  None     None              None  None  None  9751819YH3695S       None
# 1  None     None              None  None  None  9751819YH3695S       None
#
#   poblacion                          geom tip_via        lat       lng  \
# 0      None  POINT (-0.253389 38.4993434)    None  38.499343 -0.253389
# 1      None  POINT (-0.253389 38.4993434)    None  38.499343 -0.253389
#
#    portalNumber stateMsg extension  state  priority  \
# 0             0               None      0         0
# 1             0               None      0         0
#
#                                         refCatastral countryCode
# 0  PL PARAIS NORD PP 24 142 VILLAJOYOSA / LA VILA...         011
# 1  PL PARAIS NORD PP 24 142 VILLAJOYOSA / LA VILA...         011

# %%
{"id":NULL,"province":NULL,"comunidadAutonoma":NULL,"muni":NULL,"type":NULL,"address":NULL,"postalCode":NULL,"poblacion":NULL,"geom":NULL,"tip_via":NULL,"lat":NULL,"lng":NULL,"portalNumber":NULL,"stateMsg":"","extension":NULL,"state":0,"priority":0,"refCatastral":,"countryCode":"011"}
# Out:
#   File "<ipython-input-138-9f37966abeb0>", line 1
#     {"id":NULL,"province":NULL,"comunidadAutonoma":NULL,"muni":NULL,"type":NULL,"address":NULL,"postalCode":NULL,"poblacion":NULL,"geom":NULL,"tip_via":NULL,"lat":NULL,"lng":NULL,"portalNumber":NULL,"stateMsg":"","extension":NULL,"state":0,"priority":0,"refCatastral":,"countryCode":"011"}
#                                                                                                                                                                                                                                                                             ^
# SyntaxError: invalid syntax
